# %% [markdown]
# ## 广东2022年7月清洁与污染个例
# ## `GZ_2207 Clean & Pollute`
#
# ---
# *@author: Evan*\
# *@date: 2022-08-27*

# %%
import netCDF4 as nc
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
# 允许显示中文
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 读取数据

# %%
GridFile=nc.Dataset('F:/Data/caseGZ_2207/GRIDCRO2D_2022200.nc')
chemFile=nc.Dataset('F:/Data/caseGZ_2207/COMBINE_ACONC_CN3GD_152X110_202207_mech.nc')
uvFile=nc.Dataset('F:/Data/caseGZ_2207/COMBINE_ACONC_CN3GD_152X110_202207_uv_vertical.nc')

# %%
lat=np.squeeze(GridFile.variables['LAT'][:])
lon=np.squeeze(GridFile.variables['LON'][:])
NO2_L1=np.squeeze(chemFile.variables['NO2'][120:,0,:,:])*47/22.4
NO2_L2=np.squeeze(chemFile.variables['NO2'][120:,18,:,:])*47/22.4
uwind_L1=np.squeeze(uvFile.variables['UWind'][120:456,0,:110,:152])
vwind_L1=np.squeeze(uvFile.variables['VWind'][120:456,0,:110,:152])
uwind_L2=np.squeeze(uvFile.variables['UWind'][120:456,18,:110,:152])
vwind_L2=np.squeeze(uvFile.variables['VWind'][120:456,18,:110,:152])

print('lat & lon = ',lat.shape)
print('chem      = ',NO2_L1.shape)
print('wind      = ',uwind_L1.shape)
# Out:
# lat & lon =  (110, 152)
# chem      =  (336, 110, 152)
# wind      =  (336, 110, 152)

# %%
# read obs
sitelist=pd.read_excel('F:/Data/caseGZ_2207/obsdata/sitelist.xlsx')
# sites=list(sitelist['监测点编码'])
site_lon=sitelist['经度']
site_lat=sitelist['纬度']
obsdata=pd.read_excel('F:/Data/caseGZ_2207/obsdata/NO2_obs.xlsx')
obsdata
# Out:
#          date  hour  1345A  1346A  1347A  1348A  1349A  1350A  1351A  1352A  \
# 0    20220715     0   27.0   24.0    NaN   33.0   42.0   16.0   27.0   23.0
# 1    20220715     1   21.0   25.0    NaN   22.0   40.0   21.0   20.0   20.0
# 2    20220715     2   23.0   24.0    NaN   24.0   40.0   15.0   21.0   22.0
# 3    20220715     3   23.0   19.0    NaN   22.0   37.0   13.0   25.0   16.0
# 4    20220715     4   21.0   15.0    NaN   22.0   35.0   12.0   19.0   13.0
# ..        ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 331  20220728    19   25.0   25.0    NaN   26.0   36.0   19.0   13.0   17.0
# 332  20220728    20   32.0   29.0    NaN   27.0   41.0   21.0   15.0   21.0
# 333  20220728    21   35.0   30.0    NaN   29.0   33.0   18.0   16.0   28.0
# 334  20220728    22   34.0   26.0    NaN   28.0   41.0   24.0   19.0   21.0
# 335  20220728    23   26.0   25.0    NaN   40.0   47.0   23.0   41.0   19.0
#
#      ...  3451A  3452A  3453A  3454A  3455A  3622A  3623A  3626A  3627A  3628A
# 0    ...    NaN    NaN    3.0    6.0    NaN   21.0   44.0    NaN   21.0    7.0
# 1    ...    NaN    NaN    NaN    NaN    NaN   17.0    NaN    NaN    NaN    7.0
# 2    ...    4.0   28.0    2.0    6.0   16.0   13.0   26.0   20.0   19.0    7.0
# 3    ...    4.0   14.0    3.0    8.0   19.0   11.0   27.0   16.0   17.0    9.0
# 4    ...    4.0    9.0    4.0    8.0   19.0   12.0   28.0    9.0   13.0   10.0
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 331  ...    4.0    8.0    5.0    9.0    NaN   10.0   25.0   29.0   27.0   16.0
# 332  ...    4.0    8.0    4.0   10.0    6.0   11.0   31.0   30.0   24.0   19.0
# 333  ...    4.0    8.0    4.0   11.0    8.0   15.0   27.0   20.0   21.0   15.0
# 334  ...    4.0    8.0    4.0   13.0    9.0   17.0   21.0   22.0   25.0   12.0
# 335  ...    5.0    8.0    6.0   16.0    9.0   17.0   27.0   20.0   24.0   17.0
#
# [336 rows x 102 columns]

# %%
def t2step(date: 'int',hour: 'int',start_date: 'int',end_date: 'int'):
    """
    convert time point wanted to time step in model data
    """
    delt=date-start_date-1
    tstep=delt*24+16+hour
    return(tstep)

# %% [markdown]
# ## 绘图

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeat
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.io.shapereader import Reader
import datetime

# %%
shp_CN=Reader('D:/files/Master/02学术/Boundary/全国省市县九段线/省级、地市级、县市级行政区划/bou1_4l.shp')
shp_SCS=Reader('D:/files/Master/02学术/Boundary/全国省市县九段线/南海诸岛/bou2_4l.shp')
shp_GD=Reader('D:/files/Master/02学术/Boundary/地形边界/Gdbound/gdboudiv_arc.shp')
shp_HK=Reader('D:/files/Master/02学术/Boundary/行政边界/HK/HK.shp')
shp_MC=Reader('D:/files/Master/02学术/Boundary/行政边界/MC/MC.shp')
shp_GZ=Reader('D:/files/Master/02学术/Boundary/全国省市县九段线/广州市/广州市.shp')

# %% [markdown]
# ### 1.单幅图

# %%
date=22
hour=16
tstep=t2step(date,hour,15,28)

cmax=121
cmaplevel=np.arange(0,cmax,3)
# proj=ccrs.LambertConformal(central_longitude=115,standard_parallels=(15,40))
proj=ccrs.PlateCarree()
proj_shp=ccrs.PlateCarree()
fig = plt.figure(figsize=(12,4),dpi=300)
ax = fig.subplots(1,2,subplot_kw={'projection':proj})

# SHP Lines
for i in range(2):
    # ax[i].add_feature(cfeat.ShapelyFeature(shp_CN.geometries(),proj_shp,edgecolor='k',facecolor='None'), linewidth=0.5)
    # ax[i].add_feature(cfeat.ShapelyFeature(shp_SCS.geometries(),proj_shp,edgecolor='k',facecolor='None'), linewidth=0.5)
    ax[i].add_feature(cfeat.ShapelyFeature(shp_GD.geometries(),proj_shp,edgecolor='k',facecolor='None'), linewidth=0.8)
    ax[i].add_feature(cfeat.ShapelyFeature(shp_HK.geometries(),proj_shp,edgecolor='k',facecolor='None'), linewidth=0.4)
    ax[i].add_feature(cfeat.ShapelyFeature(shp_MC.geometries(),proj_shp,edgecolor='k',facecolor='None'), linewidth=0.4)

    gl=ax[i].gridlines(
        xlocs=np.arange(-180, 180 + 1, 1), ylocs=np.arange(-90, 90 + 1, 1),
        draw_labels=True, x_inline=False, y_inline=False,
        linewidth=0.5, linestyle='--', color='gray')
    gl.top_labels = False
    gl.right_labels =False
    gl.rotate_labels=False

    # ax[i].set_extent([109.5, 117.4, 20.2, 25.6],ccrs.PlateCarree())
    ax[i].set_extent([111.2, 115.6, 21.6, 24.5],ccrs.PlateCarree())


# ----------------1000hPa----------------

# contour map
cmap=ax[0].contourf(lon,lat,NO2_L1[tstep,:,:],transform=proj_shp,cmap='Spectral_r',levels=cmaplevel,extend='both')

# wind quiver
xgrid=np.size(uwind_L1,2)
ygrid=np.size(vwind_L1,1)
ngrid=8

ax[0].quiver(lon[0:ygrid:ngrid,0:xgrid:ngrid],lat[0:ygrid:ngrid,0:xgrid:ngrid],
        uwind_L1[tstep,0:ygrid:ngrid,0:xgrid:ngrid],vwind_L1[tstep,0:ygrid:ngrid,0:xgrid:ngrid],
        transform=proj_shp,color='k',alpha=1,scale=150,headwidth=3)

# station obs
for m in range(100):
    ax[0].scatter(site_lon[m],site_lat[m],transform=proj_shp,marker='o',s=20,
                  c=obsdata.iloc[(date-15)*24+hour,m+2],cmap='Spectral_r',vmin=0,vmax=cmax,edgecolors='k',linewidth=0.5)

# ----------------850hPa----------------

# contour map
cmap=ax[1].contourf(lon,lat,NO2_L2[tstep,:,:],transform=proj_shp,cmap='Spectral_r',levels=cmaplevel,extend='both')

# wind quiver
ax[1].quiver(lon[0:ygrid:ngrid,0:xgrid:ngrid],lat[0:ygrid:ngrid,0:xgrid:ngrid],
        uwind_L2[tstep,0:ygrid:ngrid,0:xgrid:ngrid],vwind_L2[tstep,0:ygrid:ngrid,0:xgrid:ngrid],
        transform=proj_shp,color='k',alpha=1,scale=150,headwidth=3)

# share colorbar
fig.subplots_adjust(right=0.9)
position= fig.add_axes([0.92,0.15,0.015,0.7])
cbar=fig.colorbar(cmap,cax=position)
cbar.set_ticks(np.arange(0,cmax+1,30))
cbar.set_label('$\mu$g/m$^3$')

# set titles
ax[0].set_title('1000hPa')
ax[1].set_title('850hPa')
plt.suptitle('NO2 at '+str(datetime.datetime(2022,7,date,hour)),size=14)
plt.show()

# %% [markdown]
# ### 2.多图

# %%
date=np.arange(15,29,1)
hour=np.arange(0,24,1)

cmax=121
cmaplevel=np.arange(0,cmax,3)
for i in range(np.size(date)):
    for j in range(np.size(hour)):
        tstep=t2step(date[i],hour[j],15,28)

        proj=ccrs.PlateCarree()
        proj_shp=ccrs.PlateCarree()
        fig = plt.figure(figsize=(12,4),dpi=300)
        ax = fig.subplots(1,2,subplot_kw={'projection':proj})

        # SHP Lines
        for k in range(2):
            ax[k].add_feature(cfeat.ShapelyFeature(shp_GD.geometries(),proj_shp,edgecolor='k',facecolor='None'), linewidth=0.8)
            ax[k].add_feature(cfeat.ShapelyFeature(shp_HK.geometries(),proj_shp,edgecolor='k',facecolor='None'), linewidth=0.4)
            ax[k].add_feature(cfeat.ShapelyFeature(shp_MC.geometries(),proj_shp,edgecolor='k',facecolor='None'), linewidth=0.4)

            gl=ax[k].gridlines(
                xlocs=np.arange(-180, 180 + 1, 1), ylocs=np.arange(-90, 90 + 1, 1),
                draw_labels=True, x_inline=False, y_inline=False,
                linewidth=0.5, linestyle='--', color='gray')
            gl.top_labels = False
            gl.right_labels =False
            gl.rotate_labels=False

            # ax[k].set_extent([109.5, 117.4, 20.2, 25.6],ccrs.PlateCarree())
            ax[k].set_extent([111.2, 115.6, 21.6, 24.5],ccrs.PlateCarree())


        # ----------------1000hPa----------------

        # contour map
        cmap=ax[0].contourf(lon,lat,NO2_L1[tstep,:,:],transform=proj_shp,cmap='Spectral_r',levels=cmaplevel,extend='both')

        # wind quiver
        xgrid=np.size(uwind_L1,2)
        ygrid=np.size(vwind_L1,1)
        ngrid=8

        ax[0].quiver(lon[0:ygrid:ngrid,0:xgrid:ngrid],lat[0:ygrid:ngrid,0:xgrid:ngrid],
                uwind_L1[tstep,0:ygrid:ngrid,0:xgrid:ngrid],vwind_L1[tstep,0:ygrid:ngrid,0:xgrid:ngrid],
                transform=proj_shp,color='k',alpha=1,scale=150,headwidth=3)

        # station obs
        for m in range(100):
            ax[0].scatter(site_lon[m],site_lat[m],transform=proj_shp,marker='o',s=20,
                  c=obsdata.iloc[(date[i]-15)*24+hour[j],m+2],cmap='Spectral_r',vmin=0,vmax=cmax,edgecolors='k',linewidth=0.5)

        # ----------------850hPa----------------

        # contour map
        cmap=ax[1].contourf(lon,lat,NO2_L2[tstep,:,:],transform=proj_shp,cmap='Spectral_r',levels=cmaplevel,extend='both')

        # wind quiver
        ax[1].quiver(lon[0:ygrid:ngrid,0:xgrid:ngrid],lat[0:ygrid:ngrid,0:xgrid:ngrid],
                uwind_L2[tstep,0:ygrid:ngrid,0:xgrid:ngrid],vwind_L2[tstep,0:ygrid:ngrid,0:xgrid:ngrid],
                transform=proj_shp,color='k',alpha=1,scale=150,headwidth=3)

        # station obs
        # for k in range(12):
        #     ax[1].scatter(df.lon[k],df.lat[k],transform=proj_shp,marker='o',s=20,
        #                   c=var_o[k,(date-18)*24+hour],cmap='Spectral_r',vmin=0,vmax=cmax,edgecolors='k',linewidth=0.5)

        # share colorbar
        fig.subplots_adjust(right=0.9)
        position= fig.add_axes([0.92,0.15,0.015,0.7])
        cbar=fig.colorbar(cmap,cax=position)
        cbar.set_ticks(np.arange(0,cmax+1,30))
        cbar.set_label('$\mu$g/m$^3$')

        # set titles
        ax[0].set_title('1000hPa')
        ax[1].set_title('850hPa')
        plt.suptitle('NO2 at '+str(datetime.datetime(2022,7,date[i],hour[j])),size=14)
        
        figure_path='F:/Data/caseGZ_2207/Figure/NO2_h/'
        plt.savefig(figure_path+str(datetime.date(2022,7,date[i]))+'_'+str(hour[j]).zfill(2)+'.png')
        print('Now printing '+str(datetime.datetime(2022,7,date[i],hour[j])))
print('Printing Completed!')
# plt.show()
# Out:
# Now printing 2022-07-15 00:00:00
# Now printing 2022-07-15 01:00:00
# Now printing 2022-07-15 02:00:00
# Now printing 2022-07-15 03:00:00
# Now printing 2022-07-15 04:00:00
# Now printing 2022-07-15 05:00:00
# Now printing 2022-07-15 06:00:00
# Now printing 2022-07-15 07:00:00
# Now printing 2022-07-15 08:00:00
# Now printing 2022-07-15 09:00:00
# Now printing 2022-07-15 10:00:00
# Now printing 2022-07-15 11:00:00
# Now printing 2022-07-15 12:00:00
# Now printing 2022-07-15 13:00:00
# Now printing 2022-07-15 14:00:00
# Now printing 2022-07-15 15:00:00
# Now printing 2022-07-15 16:00:00
# Now printing 2022-07-15 17:00:00
# Now printing 2022-07-15 18:00:00
# Now printing 2022-07-15 19:00:00
# Now printing 2022-07-15 20:00:00
# Now printing 2022-07-15 21:00:00
# Now printing 2022-07-15 22:00:00
# Now printing 2022-07-15 23:00:00
# Now printing 2022-07-16 00:00:00
# Now printing 2022-07-16 01:00:00
# Now printing 2022-07-16 02:00:00
# Now printing 2022-07-16 03:00:00
# Now printing 2022-07-16 04:00:00
# Now printing 2022-07-16 05:00:00
# Now printing 2022-07-16 06:00:00
# Now printing 2022-07-16 07:00:00
# Now printing 2022-07-16 08:00:00
# Now printing 2022-07-16 09:00:00
# Now printing 2022-07-16 10:00:00
# Now printing 2022-07-16 11:00:00
# Now printing 2022-07-16 12:00:00
# Now printing 2022-07-16 13:00:00
# Now printing 2022-07-16 14:00:00
# Now printing 2022-07-16 15:00:00
# Now printing 2022-07-16 16:00:00
# Now printing 2022-07-16 17:00:00
# Now printing 2022-07-16 18:00:00
# Now printing 2022-07-16 19:00:00
# Now printing 2022-07-16 20:00:00
# Now printing 2022-07-16 21:00:00
# Now printing 2022-07-16 22:00:00
# Now printing 2022-07-16 23:00:00
# Now printing 2022-07-17 00:00:00
# Now printing 2022-07-17 01:00:00
# Now printing 2022-07-17 02:00:00
# Now printing 2022-07-17 03:00:00
# Now printing 2022-07-17 04:00:00
# Now printing 2022-07-17 05:00:00
# Now printing 2022-07-17 06:00:00
# Now printing 2022-07-17 07:00:00
# Now printing 2022-07-17 08:00:00
# Now printing 2022-07-17 09:00:00
# Now printing 2022-07-17 10:00:00
# Now printing 2022-07-17 11:00:00
# Now printing 2022-07-17 12:00:00
# Now printing 2022-07-17 13:00:00
# Now printing 2022-07-17 14:00:00
# Now printing 2022-07-17 15:00:00
# Now printing 2022-07-17 16:00:00
# Now printing 2022-07-17 17:00:00
# Now printing 2022-07-17 18:00:00
# Now printing 2022-07-17 19:00:00
# Now printing 2022-07-17 20:00:00
# Now printing 2022-07-17 21:00:00
# Now printing 2022-07-17 22:00:00
# Now printing 2022-07-17 23:00:00
# Now printing 2022-07-18 00:00:00
# Now printing 2022-07-18 01:00:00
# Now printing 2022-07-18 02:00:00
# Now printing 2022-07-18 03:00:00
# Now printing 2022-07-18 04:00:00
# Now printing 2022-07-18 05:00:00
# Now printing 2022-07-18 06:00:00
# Now printing 2022-07-18 07:00:00
# Now printing 2022-07-18 08:00:00
# Now printing 2022-07-18 09:00:00
# Now printing 2022-07-18 10:00:00
# Now printing 2022-07-18 11:00:00
# Now printing 2022-07-18 12:00:00
# Now printing 2022-07-18 13:00:00
# Now printing 2022-07-18 14:00:00
# Now printing 2022-07-18 15:00:00
# Now printing 2022-07-18 16:00:00
# Now printing 2022-07-18 17:00:00
# Now printing 2022-07-18 18:00:00
# Now printing 2022-07-18 19:00:00
# Now printing 2022-07-18 20:00:00
# Now printing 2022-07-18 21:00:00
# Now printing 2022-07-18 22:00:00
# Now printing 2022-07-18 23:00:00
# Now printing 2022-07-19 00:00:00
# Now printing 2022-07-19 01:00:00
# Now printing 2022-07-19 02:00:00
# Now printing 2022-07-19 03:00:00
# Now printing 2022-07-19 04:00:00
# Now printing 2022-07-19 05:00:00
# Now printing 2022-07-19 06:00:00
# Now printing 2022-07-19 07:00:00
# Now printing 2022-07-19 08:00:00
# Now printing 2022-07-19 09:00:00
# Now printing 2022-07-19 10:00:00
# Now printing 2022-07-19 11:00:00
# Now printing 2022-07-19 12:00:00
# Now printing 2022-07-19 13:00:00
# Now printing 2022-07-19 14:00:00
# Now printing 2022-07-19 15:00:00
# Now printing 2022-07-19 16:00:00
# Now printing 2022-07-19 17:00:00
# Now printing 2022-07-19 18:00:00
# Now printing 2022-07-19 19:00:00
# Now printing 2022-07-19 20:00:00
# Now printing 2022-07-19 21:00:00
# Now printing 2022-07-19 22:00:00
# Now printing 2022-07-19 23:00:00
# Now printing 2022-07-20 00:00:00
# Now printing 2022-07-20 01:00:00
# Now printing 2022-07-20 02:00:00
# Now printing 2022-07-20 03:00:00
# Now printing 2022-07-20 04:00:00
# Now printing 2022-07-20 05:00:00
# Now printing 2022-07-20 06:00:00
# Now printing 2022-07-20 07:00:00
# Now printing 2022-07-20 08:00:00
# Now printing 2022-07-20 09:00:00
# Now printing 2022-07-20 10:00:00
# Now printing 2022-07-20 11:00:00
# Now printing 2022-07-20 12:00:00
# Now printing 2022-07-20 13:00:00
# Now printing 2022-07-20 14:00:00
# Now printing 2022-07-20 15:00:00
# Now printing 2022-07-20 16:00:00
# Now printing 2022-07-20 17:00:00
# Now printing 2022-07-20 18:00:00
# Now printing 2022-07-20 19:00:00
# Now printing 2022-07-20 20:00:00
# Now printing 2022-07-20 21:00:00
# Now printing 2022-07-20 22:00:00
# Now printing 2022-07-20 23:00:00
# Now printing 2022-07-21 00:00:00
# Now printing 2022-07-21 01:00:00
# Now printing 2022-07-21 02:00:00
# Now printing 2022-07-21 03:00:00
# Now printing 2022-07-21 04:00:00
# Now printing 2022-07-21 05:00:00
# Now printing 2022-07-21 06:00:00
# Now printing 2022-07-21 07:00:00
# Now printing 2022-07-21 08:00:00
# Now printing 2022-07-21 09:00:00
# Now printing 2022-07-21 10:00:00
# Now printing 2022-07-21 11:00:00
# Now printing 2022-07-21 12:00:00
# Now printing 2022-07-21 13:00:00
# Now printing 2022-07-21 14:00:00
# Now printing 2022-07-21 15:00:00
# Now printing 2022-07-21 16:00:00
# Now printing 2022-07-21 17:00:00
# Now printing 2022-07-21 18:00:00
# Now printing 2022-07-21 19:00:00
# Now printing 2022-07-21 20:00:00
# Now printing 2022-07-21 21:00:00
# Now printing 2022-07-21 22:00:00
# Now printing 2022-07-21 23:00:00
# Now printing 2022-07-22 00:00:00
# Now printing 2022-07-22 01:00:00
# Now printing 2022-07-22 02:00:00
# Now printing 2022-07-22 03:00:00
# Now printing 2022-07-22 04:00:00
# Now printing 2022-07-22 05:00:00
# Now printing 2022-07-22 06:00:00
# Now printing 2022-07-22 07:00:00
# Now printing 2022-07-22 08:00:00
# Now printing 2022-07-22 09:00:00
# Now printing 2022-07-22 10:00:00
# Now printing 2022-07-22 11:00:00
# Now printing 2022-07-22 12:00:00
# Now printing 2022-07-22 13:00:00
# Now printing 2022-07-22 14:00:00
# Now printing 2022-07-22 15:00:00
# Now printing 2022-07-22 16:00:00
# Now printing 2022-07-22 17:00:00
# Now printing 2022-07-22 18:00:00
# Now printing 2022-07-22 19:00:00
# Now printing 2022-07-22 20:00:00
# Now printing 2022-07-22 21:00:00
# Now printing 2022-07-22 22:00:00
# Now printing 2022-07-22 23:00:00
# Now printing 2022-07-23 00:00:00
# Now printing 2022-07-23 01:00:00
# Now printing 2022-07-23 02:00:00
# Now printing 2022-07-23 03:00:00
# Now printing 2022-07-23 04:00:00
# Now printing 2022-07-23 05:00:00
# Now printing 2022-07-23 06:00:00
# Now printing 2022-07-23 07:00:00
# Now printing 2022-07-23 08:00:00
# Now printing 2022-07-23 09:00:00
# Now printing 2022-07-23 10:00:00
# Now printing 2022-07-23 11:00:00
# Now printing 2022-07-23 12:00:00
# Now printing 2022-07-23 13:00:00
# Now printing 2022-07-23 14:00:00
# Now printing 2022-07-23 15:00:00
# Now printing 2022-07-23 16:00:00
# Now printing 2022-07-23 17:00:00
# Now printing 2022-07-23 18:00:00
# Now printing 2022-07-23 19:00:00
# Now printing 2022-07-23 20:00:00
# Now printing 2022-07-23 21:00:00
# Now printing 2022-07-23 22:00:00
# Now printing 2022-07-23 23:00:00
# Now printing 2022-07-24 00:00:00
# Now printing 2022-07-24 01:00:00
# Now printing 2022-07-24 02:00:00
# Now printing 2022-07-24 03:00:00
# Now printing 2022-07-24 04:00:00
# Now printing 2022-07-24 05:00:00
# Now printing 2022-07-24 06:00:00
# Now printing 2022-07-24 07:00:00
# Now printing 2022-07-24 08:00:00
# Now printing 2022-07-24 09:00:00
# Now printing 2022-07-24 10:00:00
# Now printing 2022-07-24 11:00:00
# Now printing 2022-07-24 12:00:00
# Now printing 2022-07-24 13:00:00
# Now printing 2022-07-24 14:00:00
# Now printing 2022-07-24 15:00:00
# Now printing 2022-07-24 16:00:00
# Now printing 2022-07-24 17:00:00
# Now printing 2022-07-24 18:00:00
# Now printing 2022-07-24 19:00:00
# Now printing 2022-07-24 20:00:00
# Now printing 2022-07-24 21:00:00
# Now printing 2022-07-24 22:00:00
# Now printing 2022-07-24 23:00:00
# Now printing 2022-07-25 00:00:00
# Now printing 2022-07-25 01:00:00
# Now printing 2022-07-25 02:00:00
# Now printing 2022-07-25 03:00:00
# Now printing 2022-07-25 04:00:00
# Now printing 2022-07-25 05:00:00
# Now printing 2022-07-25 06:00:00
# Now printing 2022-07-25 07:00:00
# Now printing 2022-07-25 08:00:00
# Now printing 2022-07-25 09:00:00
# Now printing 2022-07-25 10:00:00
# Now printing 2022-07-25 11:00:00
# Now printing 2022-07-25 12:00:00
# Now printing 2022-07-25 13:00:00
# Now printing 2022-07-25 14:00:00
# Now printing 2022-07-25 15:00:00
# Now printing 2022-07-25 16:00:00
# Now printing 2022-07-25 17:00:00
# Now printing 2022-07-25 18:00:00
# Now printing 2022-07-25 19:00:00
# Now printing 2022-07-25 20:00:00
# Now printing 2022-07-25 21:00:00
# Now printing 2022-07-25 22:00:00
# Now printing 2022-07-25 23:00:00
# Now printing 2022-07-26 00:00:00
# Now printing 2022-07-26 01:00:00
# Now printing 2022-07-26 02:00:00
# Now printing 2022-07-26 03:00:00
# Now printing 2022-07-26 04:00:00
# Now printing 2022-07-26 05:00:00
# Now printing 2022-07-26 06:00:00
# Now printing 2022-07-26 07:00:00
# Now printing 2022-07-26 08:00:00
# Now printing 2022-07-26 09:00:00
# Now printing 2022-07-26 10:00:00
# Now printing 2022-07-26 11:00:00
# Now printing 2022-07-26 12:00:00
# Now printing 2022-07-26 13:00:00
# Now printing 2022-07-26 14:00:00
# Now printing 2022-07-26 15:00:00
# Now printing 2022-07-26 16:00:00
# Now printing 2022-07-26 17:00:00
# Now printing 2022-07-26 18:00:00
# Now printing 2022-07-26 19:00:00
# Now printing 2022-07-26 20:00:00
# Now printing 2022-07-26 21:00:00
# Now printing 2022-07-26 22:00:00
# Now printing 2022-07-26 23:00:00
# Now printing 2022-07-27 00:00:00
# Now printing 2022-07-27 01:00:00
# Now printing 2022-07-27 02:00:00
# Now printing 2022-07-27 03:00:00
# Now printing 2022-07-27 04:00:00
# Now printing 2022-07-27 05:00:00
# Now printing 2022-07-27 06:00:00
# Now printing 2022-07-27 07:00:00
# Now printing 2022-07-27 08:00:00
# Now printing 2022-07-27 09:00:00
# Now printing 2022-07-27 10:00:00
# Now printing 2022-07-27 11:00:00
# Now printing 2022-07-27 12:00:00
# Now printing 2022-07-27 13:00:00
# Now printing 2022-07-27 14:00:00
# Now printing 2022-07-27 15:00:00
# Now printing 2022-07-27 16:00:00
# Now printing 2022-07-27 17:00:00
# Now printing 2022-07-27 18:00:00
# Now printing 2022-07-27 19:00:00
# Now printing 2022-07-27 20:00:00
# Now printing 2022-07-27 21:00:00
# Now printing 2022-07-27 22:00:00
# Now printing 2022-07-27 23:00:00
# Now printing 2022-07-28 00:00:00
# Now printing 2022-07-28 01:00:00
# Now printing 2022-07-28 02:00:00
# Now printing 2022-07-28 03:00:00
# Now printing 2022-07-28 04:00:00
# Now printing 2022-07-28 05:00:00
# Now printing 2022-07-28 06:00:00
# Now printing 2022-07-28 07:00:00
# Now printing 2022-07-28 08:00:00
# Now printing 2022-07-28 09:00:00
# Now printing 2022-07-28 10:00:00
# Now printing 2022-07-28 11:00:00
# Now printing 2022-07-28 12:00:00
# Now printing 2022-07-28 13:00:00
# Now printing 2022-07-28 14:00:00
# Now printing 2022-07-28 15:00:00
# Now printing 2022-07-28 16:00:00
# Now printing 2022-07-28 17:00:00
# Now printing 2022-07-28 18:00:00
# Now printing 2022-07-28 19:00:00
# Now printing 2022-07-28 20:00:00
# Now printing 2022-07-28 21:00:00
# Now printing 2022-07-28 22:00:00
# Now printing 2022-07-28 23:00:00
# Printing Completed!
